# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

T_MAX = 300
N_LAPS = 49

import numpy as np
import scipy.stats

# %%
def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, h, m-h, m+h

# %% [markdown]
# ## MCTS Planners return distribution

# %%
china_extra = np.load("/mnt/c/Users/Diego/Desktop/Logs/China_extra_pit/numpy_dumps/results.npy")
print(mean_confidence_interval(monza_planner))

china = np.load("/mnt/c/Users/Diego/Desktop/Logs/China_2018_QL_LR_schedule_a05_b2_SC/numpy_dumps/results.npy")
print(mean_confidence_interval(china))
# Out:
# (-5110.396363613953, 3.3304278971678345, -5113.7267915111215, -5107.065935716785)
# (-5106.059649664383, 2.0632028249216128, -5108.122852489305, -5103.996446839461)

# %%
a05_b3 = np.load("/mnt/c/Users/Diego/Desktop/Logs/Austria_2017_QL_LR_Schedule_a05_b3/numpy_dumps/results.npy")
a02_b2 = np.load("/mnt/c/Users/Diego/Desktop/Logs/Austria_2017_QL_LR_Schedule_a-02_b-2/numpy_dumps/results.npy")
a1_b3_VSE = np.load("/mnt/c/Users/Diego/Desktop/Logs/Austria_2017_QL_LR_Schedule_a1_b3_VSE/numpy_dumps/results.npy")
a1_b3 = np.load("/mnt/c/Users/Diego/Desktop/Logs/Austria_2017_QL_LR_Schedule_a1_b3/numpy_dumps/results.npy")
K100 = np.load("/mnt/c/Users/Diego/Desktop/Logs/Austria_2017_QL_LR_Schedule_100K/numpy_dumps/results.npy")

# %%
true_strategy_scores = np.load("../data/RaceStrategy-v2/human_policy/results_unnorm_ost_2017.npy")

# %%
true_sampled = np.random.choice(true_strategy_scores.squeeze(), 100, replace=True)
#true_sampled = true_strategy_scores.squeeze()

results = np.hstack([a05_b3.squeeze(), 
a02_b2.squeeze(), 
a1_b3_VSE.squeeze(), 
a1_b3.squeeze(), 
K100.squeeze(),
true_sampled])

labels = ["budget 10K, LR a=0.5, b=3"] * len(a05_b3)
labels.extend(["budget 10K, LR a=0.2, b=2"] * len(a02_b2))
labels.extend(["budget 10K, LR a=1, b=3 + VSE"] * len(a1_b3_VSE))
labels.extend(["budget 10K, LR a=0.2, b=2"] * len(a1_b3))
labels.extend(["budget 100K, LR a=1, b=3"] * len(K100))
labels.extend(["True"] * len(true_sampled))

sets = ["Planner"] * len(a05_b3)
sets.extend(["Planner"] * len(a02_b2))
sets.extend(["Planner"] * len(a1_b3_VSE))
sets.extend(["Planner"] * len(a1_b3))
sets.extend(["Planner"] * len(K100))
sets.extend(["GT"] * len(true_sampled))

print(len(labels), len(results), len(sets))

df = pd.DataFrame({"planner": labels, "return":results, "set": sets})
# Out:
# 600 600 600

# %%
fig = plt.figure(figsize=(15, 10))
plt.title("Austria 2017 - return visualization")
sns.violinplot(x="return", y="planner", data=df, inner="point")
plt.vlines(x=np.mean(true_strategy_scores), ymin=0, ymax=len(df['planner'].unique())-1, colors=['blue'])
plt.savefig("../figures/violin_aus_2017.jpg", bbox_inches='tight')

# %%
fig = plt.figure(figsize=(15, 10))
sns.catplot(x="return", y="planner", data=df, jitter=False, hue="set", aspect=2, height=8)
plt.title("Austria 2017 - return visualization")
plt.vlines(x=np.mean(true_strategy_scores), ymin=0, ymax=len(df['planner'].unique())-1, colors=['red'])
plt.show()
plt.savefig("../figures/categorical_aus_2017.jpg", bbox_inches='tight')

# %%
plt.figure(figsize=(10, 5))
sns.pointplot(x="return", y="planner", join=False, data=df, ci=95, hue="set")
#plt.vlines(x=np.mean(true_strategy_scores), ymin=0, ymax=len(df['planner'].unique())-1, colors=['red'])
plt.title("Austria 2017 - return mean and 95% ci")
plt.show()
plt.savefig("../figures/mean95ci_aus_2017.jpg")

# %%
ol_uct_offline_scores_1_old = np.load("../logs/RaceStrategy-v2/ol_uct_var/2020-10-31_16-31/results.npy")
ol_uct_offline_scores_2_old = np.load("../logs/RaceStrategy-v2/ol_uct_var/2020-10-31_16-34/results.npy")
ol_uct_offline_scores_3_old = np.load("../logs/RaceStrategy-v2/ol_uct_var/2020-10-31_16-35/results.npy")

# %%
fig = plt.figure()
sns.distplot(ol_uct_offline_scores_1, label='budget 50k + sch', hist=False)
sns.distplot(ol_uct_offline_scores_1_old, label='budget 20k', hist=False)
sns.distplot(default_strategy_scores, label='Default', hist=False)
sns.distplot(true_strategy_scores, label='True', hist=False)
plt.title('Return for OL - Australia 2017 - csi=5, c=1')
plt.legend(loc='best')
plt.savefig('../figures/ol_uct_set1_aus_2017_comparison_unnorm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ddb4543468b7> in <module>
#       1 fig = plt.figure()
# ----> 2 sns.distplot(ol_uct_offline_scores_1, label='budget 50k + sch', hist=False)
#       3 sns.distplot(ol_uct_offline_scores_1_old, label='budget 20k', hist=False)
#       4 sns.distplot(default_strategy_scores, label='Default', hist=False)
#       5 sns.distplot(true_strategy_scores, label='True', hist=False)
#
# NameError: name 'ol_uct_offline_scores_1' is not defined

# %%
fig = plt.figure()
sns.distplot(ol_uct_offline_scores_2, label='budget 50k + sch', hist=False)
sns.distplot(ol_uct_offline_scores_2_old, label='budget 20k', hist=False)
sns.distplot(default_strategy_scores, label='Default', hist=False)
sns.distplot(true_strategy_scores, label='True', hist=False)
plt.title('Return for OL - Australia 2017 - csi=1, c=2.5')
plt.legend(loc='best')
plt.savefig('../figures/ol_uct_set2_aus_2017_comparison_unnorm')
plt.show()

# %%
fig = plt.figure()
sns.distplot(ol_uct_offline_scores_3, label='budget 50k + sch', hist=False)
sns.distplot(ol_uct_offline_scores_3_old, label='budget 20k', hist=False)
sns.distplot(default_strategy_scores, label='Default', hist=False)
sns.distplot(true_strategy_scores, label='True', hist=False)
plt.title('Return for OL - Australia 2017 - csi=2.5, c=1')
plt.legend(loc='best')
plt.savefig('../figures/ol_uct_set3_aus_2017_comparison_unnorm')
plt.show()

# %% [markdown]
# ## csi parameter evaluation

# %%
set_1 = np.load("../logs/RaceStrategy-v2/ol_uct_var/2020-11-05_16-18-19/results.npy")
set_2 = np.load("../logs/RaceStrategy-v2/ol_uct_var/2020-11-05_16-49-22/results.npy")
set_3 = np.load("../logs/RaceStrategy-v2/ol_uct_var/2020-11-05_17-20-45/results.npy")
set_4 = np.load("../logs/RaceStrategy-v2/ol_uct_var/2020-11-05_17-50-32/results.npy")
set_5 = np.load("../logs/RaceStrategy-v2/ol_uct_var/2020-11-05_18-22-30/results.npy")
set_6 = np.load("../logs/RaceStrategy-v2/ol_uct_var/2020-11-05_18-53-59/results.npy")

# %%
set_list = [set_1, set_2, set_3, set_4, set_5, set_6]
csi_list = [1, 2.5, 5, 10, 30, 50]
df_list = []
for s, csi in zip(set_list, csi_list):
    df_list.append(pd.DataFrame({"ret": s, "csi": csi}))
df = pd.concat(df_list)

plt.figure()
plt.title("AUS 2017 - return comparison - c=2.5, budget 10k uniform ")
sns.lineplot(x="csi", y="ret", data=df, ci="sd")
plt.hlines(y=[np.mean(true_strategy_scores), np.mean(default_strategy_scores)], xmin=[0,0], xmax=[50,50], colors=["red", "green"])
plt.savefig("../figures/ol_uct_csi_comparison_AUS_2017_10000b_uniform")

# %% [markdown]
# ## TRPO return distribution

# %%
trpo_logs_folder = "../data/RaceStrategy-v2/trpo_2_32_0.001_201e/logs/"
training_scores = []

for dir in os.scandir(trpo_logs_folder):
    training_scores.append(np.load(dir.path + "/final_evaluation_scores.npy", allow_pickle=True))

plt.figure()
for data in training_scores:
    sns.distplot(data, hist=False)
plt.title("TRPO return distribution for training on same parameters")
plt.savefig('../logs/RaceStrategy-v2/trpo/return_2x32_5tr.png')
plt.show()

# %%
trpo_logs_folder = "../data/RaceStrategy-v2/trpo_2_32_0.001_201e/logs/"
training_scores = []

for dir in os.scandir(trpo_logs_folder):
    training_scores.append(np.load(dir.path + "/final_evaluation_scores.npy", allow_pickle=True))

plt.figure()
for data in training_scores:
    sns.distplot(data, hist=False)
plt.title("TRPO return distribution for training on same parameters")
plt.savefig('../logs/RaceStrategy-v2/trpo/return_2x32_5tr.png')
plt.show()

# %%
full_scores = np.hstack(training_scores)
plt.figure()
plt.title("Return distribution comparison on RaceStrategy-v2")
sns.distplot(full_scores, hist=False, label="TRPO 2x32")
sns.distplot(true_strategy_scores, hist=False, label="True strategy")
sns.distplot(default_strategy_scores, hist=False, label = "Default strategy")
plt.savefig('../logs/RaceStrategy-v2/trpo/return_comparison_2x32_5tr.png')
plt.show()

# %% [markdown]
# ## TRPO training curves

# %%
training_data_path = "../data/RaceStrategy-v2/trpo_2_32_0.001/models"

online_scores = []

for dir in os.scandir(training_data_path):
    online_scores.append(np.load(dir.path + "/online_scores.npy", allow_pickle=True))

plt.figure()
print(online_scores)
for data in online_scores:
    sns.lineplot(data=data)
plt.title("TRPO return distribution for training on same parameters")
plt.savefig('../logs/RaceStrategy-v2/trpo/return_2x32_5tr.png')
plt.show()
# Out:
# [array([7.50119862, 7.49782298, 7.50831369, 7.51434924, 7.4995782 ,
#        7.50735866, 7.50477166, 7.49736818, 7.50685504, 7.51087755,
#        7.50935678, 7.50016438, 7.51253863, 7.49200684, 7.505911  ,
#        7.52012773, 7.51325715, 7.49534052, 7.51132003, 7.50435738,
#        7.50390335, 7.50454457, 7.50963123, 7.50690953, 7.52124046,
#        7.51153791, 7.50198579, 7.49951297, 7.49403015, 7.50457377,
#        7.51507311, 7.51213507, 7.49625036, 7.51036115, 7.50320857,
#        7.51648955, 7.52423067, 7.5072741 , 7.49972709, 7.51222246,
#        7.50942443, 7.50433333, 7.52483394, 7.51045331, 7.51386529,
#        7.51066544, 7.50989436, 7.50994004, 7.51637092, 7.50846557,
#        7.51694505, 7.50550895, 7.51318934, 7.5049642 , 7.50565835,
#        7.51308725, 7.50716116, 7.50277033, 7.52106597, 7.5206327 ,
#        7.50540066, 7.50656701, 7.51488545, 7.52608663, 7.50375473,
#        7.50432677, 7.51778779, 7.50837407, 7.52116801, 7.51037597,
#        7.52896206, 7.51508284, 7.51631723, 7.50786711, 7.51226692,
#        7.52002055, 7.52786609, 7.50020529, 7.5094812 , 7.51316049,
#        7.52561744, 7.51067191, 7.51843188, 7.51080717, 7.51205209,
#        7.51396902, 7.52474496, 7.51524986, 7.51655342, 7.51727724,
#        7.52614745, 7.51738785, 7.51529778, 7.52169577, 7.52290224,
#        7.5355481 , 7.53281593, 7.51735784, 7.5096522 , 7.53608332,
#        7.52104868, 7.52683952, 7.53233151, 7.53270721, 7.53976205,
#        7.5349105 , 7.52964411, 7.53226528, 7.5363727 , 7.536587  ,
#        7.53977866, 7.54268448, 7.53616335, 7.53096643, 7.53683807,
#        7.53349072, 7.54091717, 7.53075646, 7.5360111 , 7.53575601,
#        7.54690301, 7.54408033, 7.5513226 , 7.54870912, 7.53645231,
#        7.52935458, 7.5313645 , 7.54665891, 7.53795542, 7.53302074,
#        7.53897072, 7.54485501, 7.5527446 , 7.53375365, 7.54394942,
#        7.5378401 , 7.54842325, 7.54592741, 7.53719763, 7.53457039,
#        7.54182756, 7.54777015, 7.5534751 , 7.53805783, 7.54830024,
#        7.55782108, 7.56051269, 7.57437143, 7.5595872 , 7.56904515,
#        7.56274259, 7.55121618, 7.57612746, 7.56477387, 7.57114956,
#        7.57350432, 7.57195976, 7.55922783, 7.56725774, 7.58641547,
#        7.60503115, 7.5767095 , 7.60420525, 7.59000256, 7.62156219,
#        7.60925572, 7.62314941, 7.63257126, 7.62861644, 7.62299234,
#        7.6189915 , 7.63517238, 7.63790401, 7.63127109, 7.62627555,
#        7.62245876, 7.64659801, 7.65034756, 7.64753067, 7.65118605,
#        7.65127715, 7.65542574, 7.65816932, 7.67822379, 7.68045256,
#        7.67891936, 7.69776273, 7.68851851, 7.69297879, 7.70091752,
#        7.71105611, 7.70495554, 7.69274558, 7.71031379, 7.71242791,
#        7.70537423, 7.71668656, 7.71506035, 7.71864602, 7.71858293,
#        7.72424218, 7.71570048, 7.72033356]), array([7.49953816, 7.50202212, 7.50212218, 7.50771606, 7.50567918,
#        7.49816931, 7.49952541, 7.50510316, 7.50244541, 7.49754203,
#        7.50323028, 7.50760125, 7.50591026, 7.49687311, 7.51036899,
#        7.50013394, 7.48853895, 7.50521022, 7.51184824, 7.50609817,
#        7.51161607, 7.50631959, 7.49826263, 7.50955236, 7.51956559,
#        7.51342397, 7.51587362, 7.48736074, 7.50530017, 7.52311225,
#        7.52503707, 7.5105816 , 7.51374241, 7.52340187, 7.50239703,
#        7.51826386, 7.50601868, 7.51706287, 7.50807322, 7.52772273,
#        7.51298169, 7.51467184, 7.51310338, 7.51124339, 7.51162921,
#        7.50735339, 7.51751333, 7.51233629, 7.51146511, 7.51438388,
#        7.51046693, 7.5050166 , 7.50623863, 7.51353714, 7.51526199,
#        7.49986865, 7.51737697, 7.50145557, 7.51403059, 7.51329403,
#        7.5281464 , 7.50935931, 7.52948799, 7.51704669, 7.49764968,
#        7.51964962, 7.52280824, 7.52550729, 7.52346603, 7.50640543,
#        7.53926768, 7.51437322, 7.51526696, 7.52402203, 7.53271125,
#        7.5249603 , 7.52182947, 7.52345238, 7.52291456, 7.52155788,
#        7.50687949, 7.51951715, 7.54060471, 7.5169187 , 7.52260861,
#        7.52262222, 7.49290931, 7.52370263, 7.52789994, 7.51191316,
#        7.51457362, 7.51057457, 7.52442413, 7.52466713, 7.53303443,
#        7.53320821, 7.52717854, 7.51925516, 7.53119041, 7.52563326,
#        7.54227738, 7.5135508 , 7.52932157, 7.52422815, 7.53188109,
#        7.53107105, 7.52334726, 7.52526654, 7.52763691, 7.53258746,
#        7.53255448, 7.55008192, 7.5454303 , 7.54636102, 7.53038024,
#        7.54261357, 7.53249803, 7.54069602, 7.52897293, 7.54636692,
#        7.5520826 , 7.5478703 , 7.54505213, 7.55854792, 7.53869935,
#        7.56211787, 7.54709196, 7.55176974, 7.53373189, 7.54013046,
#        7.56695062, 7.55539281, 7.56407708, 7.56959448, 7.56530932,
#        7.56075611, 7.5592389 , 7.57428932, 7.57403504, 7.57174953,
#        7.56197604, 7.56980307, 7.57881084, 7.58766774, 7.59496936,
#        7.57487728, 7.58326878, 7.59885486, 7.59981174, 7.5957949 ,
#        7.58800255, 7.5981236 , 7.60226555, 7.59707523, 7.59032121,
#        7.60415428, 7.61608671, 7.60725512, 7.62070417, 7.6051531 ,
#        7.63762628, 7.63543713, 7.63559047, 7.62244717, 7.63471757,
#        7.62484359, 7.63554403, 7.64839409, 7.63606837, 7.65691916,
#        7.65071138, 7.6464262 , 7.66371134, 7.66637151, 7.65499614,
#        7.66130595, 7.6708088 , 7.67133034, 7.6830123 , 7.66886487,
#        7.68124654, 7.67917685, 7.67603732, 7.6709407 , 7.66756718,
#        7.67660092, 7.67815964, 7.68106537, 7.67148481, 7.66309067,
#        7.67821402, 7.67857001, 7.67794994, 7.68371037, 7.66584584,
#        7.6801711 , 7.68569355, 7.69058667, 7.67656757, 7.68289254,
#        7.67650789, 7.67246278, 7.67054569]), array([7.50370163, 7.52215833, 7.50599956, 7.51299788, 7.49665598,
#        7.50199719, 7.50845039, 7.4951363 , 7.49431413, 7.50818251,
#        7.50592718, 7.50157337, 7.49606937, 7.5075819 , 7.49501769,
#        7.50581478, 7.48563275, 7.49045699, 7.50378894, 7.49469057,
#        7.50931235, 7.50107975, 7.51662734, 7.50831808, 7.49936746,
#        7.50630451, 7.49810538, 7.50254568, 7.48516446, 7.52303284,
#        7.5046909 , 7.49903424, 7.49707283, 7.49629336, 7.49857036,
#        7.50172084, 7.47405144, 7.4893517 , 7.49036012, 7.49429988,
#        7.50244504, 7.49892341, 7.48733952, 7.49449639, 7.49076897,
#        7.50294996, 7.50308328, 7.51013689, 7.50138338, 7.48617218,
#        7.51680855, 7.50517694, 7.4916719 , 7.50438145, 7.48675815,
#        7.50494402, 7.50788649, 7.50948082, 7.50078574, 7.51378063,
#        7.50145059, 7.50210526, 7.50030929, 7.51102836, 7.51223265,
#        7.51044615, 7.51557516, 7.49388264, 7.50063125, 7.48524947,
#        7.51553805, 7.50381659, 7.5191032 , 7.51619129, 7.51734981,
#        7.50429787, 7.50543099, 7.50720395, 7.51901066, 7.51761712,
#        7.51244266, 7.50868872, 7.51405288, 7.49227768, 7.51572943,
#        7.5099304 , 7.51501537, 7.50244506, 7.49803172, 7.50990084,
#        7.51871641, 7.51171079, 7.49805255, 7.51995265, 7.52340173,
#        7.51962712, 7.52994192, 7.52923749, 7.51644173, 7.52142632,
#        7.52030794, 7.53419819, 7.51656459, 7.54347082, 7.54285353,
#        7.52659281, 7.54486759, 7.53125887, 7.51868483, 7.51958412,
#        7.51892905, 7.53865913, 7.5525838 , 7.51930289, 7.5430641 ,
#        7.53837115, 7.53960432, 7.54660559, 7.54846003, 7.56024711,
#        7.56447641, 7.54941755, 7.56578432, 7.55685988, 7.56303879,
#        7.561068  , 7.57624818, 7.56476052, 7.55812371, 7.5665612 ,
#        7.571661  , 7.58401783, 7.53474347, 7.58628246, 7.57251908,
#        7.57314206, 7.57506088, 7.57304009, 7.60991194, 7.5928465 ,
#        7.58799927, 7.59840763, 7.59931543, 7.62248535, 7.58269498,
#        7.59333042, 7.59959268, 7.62628088, 7.60502   , 7.61475597,
#        7.60515807, 7.60596308, 7.61243474, 7.63968479, 7.63786711,
#        7.60519712, 7.62183042, 7.61639604, 7.63480825, 7.62789337,
#        7.64779632, 7.63311278, 7.63803145, 7.63166914, 7.64354826,
#        7.61097898, 7.64003388, 7.64573302, 7.63192177, 7.6647744 ,
#        7.65721473, 7.63621554, 7.65296614, 7.65544086, 7.654597  ,
#        7.64825853, 7.65682571, 7.67938429, 7.66181039, 7.66702705,
#        7.66521374, 7.67934094, 7.69511449, 7.69193411, 7.67842623,
#        7.68830519, 7.67410588, 7.69501626, 7.70294386, 7.70123354,
#        7.69415892, 7.68455638, 7.69856394, 7.68488348, 7.68197844,
#        7.6758892 , 7.69526221, 7.69813888, 7.6912172 , 7.68144151,
#        7.69061111, 7.69845228, 7.69727632]), array([7.50462197, 7.51820209, 7.50798811, 7.5063237 , 7.51328231,
#        7.50234079, 7.50660672, 7.4990868 , 7.49173105, 7.52229761,
#        7.5110904 , 7.50720034, 7.50379926, 7.50421338, 7.50562016,
#        7.50177325, 7.50752774, 7.50513491, 7.50972415, 7.51124401,
#        7.51105567, 7.50350504, 7.49390117, 7.50702301, 7.49740518,
#        7.49116779, 7.50339694, 7.51122177, 7.50729592, 7.50140805,
#        7.50809369, 7.49737043, 7.50774437, 7.51320119, 7.49415374,
#        7.50985952, 7.49448924, 7.49630145, 7.50317303, 7.50013454,
#        7.51006055, 7.50391037, 7.5034463 , 7.51159318, 7.49156538,
#        7.50161897, 7.51611142, 7.51507326, 7.50082599, 7.50500244,
#        7.49135836, 7.49831496, 7.50266508, 7.50388103, 7.50278332,
#        7.49889478, 7.51332439, 7.51080771, 7.51555567, 7.51917658,
#        7.50856588, 7.4994945 , 7.50402867, 7.51195053, 7.4941032 ,
#        7.50138779, 7.50818309, 7.50109612, 7.48925132, 7.49937233,
#        7.4990167 , 7.50996027, 7.50215542, 7.51728009, 7.52242695,
#        7.50243757, 7.51581774, 7.50797091, 7.51298508, 7.51927732,
#        7.51186781, 7.51660905, 7.51105569, 7.50222781, 7.52304086,
#        7.52294023, 7.50871904, 7.51882419, 7.53469791, 7.51532217,
#        7.51353431, 7.51726559, 7.53459003, 7.50624548, 7.5254149 ,
#        7.52095393, 7.51446269, 7.54121518, 7.5159986 , 7.52547329,
#        7.52070852, 7.526478  , 7.52317761, 7.52652923, 7.54354798,
#        7.52987444, 7.51730392, 7.52896727, 7.54196428, 7.53643469,
#        7.53761765, 7.54870969, 7.55251176, 7.55063865, 7.55726015,
#        7.54913293, 7.55505868, 7.55171449, 7.53421374, 7.55107232,
#        7.55114679, 7.55891444, 7.54014773, 7.57230475, 7.56077034,
#        7.56362577, 7.54963239, 7.57098607, 7.56337733, 7.56637657,
#        7.56966647, 7.55358259, 7.5536062 , 7.55774865, 7.56987174,
#        7.55843028, 7.56628664, 7.57858109, 7.58055592, 7.57657738,
#        7.58763711, 7.56224973, 7.58152674, 7.58285419, 7.57027532,
#        7.59286972, 7.56869523, 7.58305169, 7.59031153, 7.57660088,
#        7.60618424, 7.58995922, 7.59162241, 7.61479554, 7.61289013,
#        7.62565623, 7.61254717, 7.62172559, 7.6285437 , 7.62923806,
#        7.63904641, 7.61364044, 7.62895425, 7.62286303, 7.63194785,
#        7.6648898 , 7.65492943, 7.64329623, 7.66627185, 7.67059475,
#        7.66240265, 7.67529281, 7.66412045, 7.65781816, 7.66771076,
#        7.65964586, 7.66076886, 7.68031619, 7.69146248, 7.68611372,
#        7.6951015 , 7.68704844, 7.68404914, 7.69497547, 7.68916456,
#        7.69059752, 7.69211081, 7.69102553, 7.70367297, 7.69881414,
#        7.70044636, 7.69777214, 7.71076161, 7.71642814, 7.70307288,
#        7.70289092, 7.7023883 , 7.69598791, 7.70854713, 7.69144909,
#        7.70670503, 7.70563139, 7.69918047]), array([7.50120327, 7.50514859, 7.51005211, 7.5213507 , 7.4942336 ,
#        7.51358453, 7.51909122, 7.50690577, 7.51678832, 7.50516229,
#        7.50075062, 7.5078823 , 7.496951  , 7.50543468, 7.50924308,
#        7.51056214, 7.50415525, 7.5063833 , 7.5068797 , 7.51171438,
#        7.50637148, 7.50858368, 7.49946729, 7.5042195 , 7.52257775,
#        7.49124947, 7.51076972, 7.51639812, 7.51788254, 7.5021461 ,
#        7.5051421 , 7.51732757, 7.50817034, 7.51110288, 7.49559514,
#        7.51022466, 7.51052324, 7.50530697, 7.5060629 , 7.51666204,
#        7.50339275, 7.50835113, 7.51275452, 7.50737666, 7.51783961,
#        7.51157201, 7.50938035, 7.50543065, 7.50345418, 7.50110993,
#        7.50243084, 7.50695388, 7.50899105, 7.52288725, 7.50965063,
#        7.51394997, 7.53199985, 7.5098197 , 7.52027397, 7.52032215,
#        7.51869051, 7.51229158, 7.50190619, 7.50891177, 7.52642669,
#        7.50886067, 7.51319446, 7.50751057, 7.52407986, 7.50034246,
#        7.50942486, 7.52964098, 7.51697913, 7.51856556, 7.5139315 ,
#        7.51864867, 7.51853117, 7.53581062, 7.51178059, 7.51856337,
#        7.5107364 , 7.50997758, 7.51790422, 7.51854963, 7.52526289,
#        7.52897902, 7.51521989, 7.52809093, 7.51762245, 7.51585345,
#        7.52096641, 7.51396463, 7.52931558, 7.52875297, 7.53416613,
#        7.5345456 , 7.52151789, 7.52956648, 7.50988031, 7.51981299,
#        7.53389822, 7.52246217, 7.52447602, 7.51068938, 7.51968087,
#        7.51066813, 7.51330383, 7.53014496, 7.51677256, 7.52054387,
#        7.51793368, 7.51486088, 7.51846355, 7.51458305, 7.5173208 ,
#        7.51684743, 7.52440941, 7.52631222, 7.5140793 , 7.52813834,
#        7.5209706 , 7.52744591, 7.51909907, 7.52187709, 7.52653437,
#        7.50526367, 7.53576191, 7.53042411, 7.53549221, 7.52956606,
#        7.52536571, 7.5262774 , 7.51486257, 7.52804067, 7.52075637,
#        7.52992156, 7.52749406, 7.53121634, 7.54007712, 7.53131689,
#        7.54532529, 7.53143494, 7.52741347, 7.52204633, 7.53617315,
#        7.54032526, 7.52627342, 7.53522932, 7.53658032, 7.53282581,
#        7.54719991, 7.54297158, 7.5416001 , 7.54060651, 7.53756642,
#        7.55051624, 7.54995664, 7.55546502, 7.56699712, 7.54792675,
#        7.55524072, 7.551659  , 7.55620805, 7.56291536, 7.55088357,
#        7.56275405, 7.55748332, 7.55524041, 7.55847725, 7.56259802,
#        7.54636881, 7.56662251, 7.55282478, 7.55597443, 7.55223471,
#        7.5556687 , 7.5574695 , 7.56243727, 7.5511049 , 7.56210774,
#        7.55009755, 7.55662458, 7.55630023, 7.55920926, 7.55643394,
#        7.55265352, 7.55544696, 7.56506972, 7.553393  , 7.56753441,
#        7.57433489, 7.56122837, 7.57211158, 7.56083128, 7.5633252 ,
#        7.57924001, 7.57032724, 7.57525258, 7.58847708, 7.57964518,
#        7.56640177, 7.5762561 ])]
